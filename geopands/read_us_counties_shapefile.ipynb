# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Read shapefile

# %%
us_counties = gpd.read_file("zip://./data/US_County_Boundaries.zip")
us_counties.head()
# Out:
#   STFIPS CTFIPS   STATE               COUNTY VERSION  Shape_Leng  Shape_Area  \
# 0     02  02016  Alaska       Aleutians West      05   62.576763    1.540013
# 1     02  02290  Alaska        Yukon-Koyukuk      05   63.135667   74.225260
# 2     02  02185  Alaska          North Slope      05  130.327563   52.678634
# 3     02  02188  Alaska     Northwest Arctic      05   88.348799   19.328173
# 4     02  02240  Alaska  Southeast Fairbanks      05   21.362151   11.848211
#
#                                             geometry
# 0  MULTIPOLYGON (((-170.34620 57.21312, -170.3328...
# 1  POLYGON ((-147.99746 64.34170, -148.04161 64.3...
# 2  MULTIPOLYGON (((-149.74913 70.49325, -149.7479...
# 3  MULTIPOLYGON (((-162.52343 66.04237, -162.5296...
# 4  POLYGON ((-146.48418 63.17392, -146.48920 63.2...

# %%
us_counties.shape
# Out:
# (3219, 8)

# %%
us_counties.plot(figsize=(20, 12))
# Out:
# <AxesSubplot:>

# %%
ax = us_counties.plot(figsize=(20, 20))
ax.set(xlim=(-180, -60))
# Out:
# [(-180.0, -60.0)]

# %%
ax = us_counties.plot(figsize=(20, 20))
ax.set(xlim=(-130, -60), ylim=(25, 50))
# Out:
# [(-130.0, -60.0), (25.0, 50.0)]

# %%
us_counties.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
