# %%
import mapbox
from config import my_token

# %%
geocoder = mapbox.Geocoder(access_token=my_token)

# %%
response = geocoder.forward('Chester, NJ')
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'query': ['chester', 'nj'],
#  'features': [{'id': 'place.2231300684375880',
#    'type': 'Feature',
#    'place_type': ['place'],
#    'relevance': 1,
#    'properties': {'wikidata': 'Q3014459'},
#    'text': 'Chester',
#    'place_name': 'Chester, New Jersey, United States',
#    'bbox': [-74.740621662, 40.732998091, -74.623717003, 40.834595959],
#    'center': [-74.6968, 40.7843],
#    'geometry': {'type': 'Point', 'coordinates': [-74.6968, 40.7843]},
#    'context': [{'id': 'district.15641134561761970',
#      'wikidata': 'Q498163',
#      'text': 'Morris County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'poi.1254130452054',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 0.74,
#    'properties': {'foursquare': '4d90c252c1b1721e3aac6246',
#     'landmark': True,
#     'address': 'New Jersey Turnpilke',
#     'category': 'toll booth, toll plaza, toll, booth, barrier'},
#    'text': 'NJ Turnpike Toll Plaza',
#    'place_name': 'NJ Turnpike Toll Plaza, New Jersey Turnpilke, Carneys Point, New Jersey 08069, United States',
#    'center': [-75.447135, 39.686311],
#    'geometry': {'coordinates': [-75.447135, 39.686311], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.16849788063142460',
#      'text': 'Danceys Corner'},
#     {'id': 'postcode.6047690026045290', 'text': '08069'},
#     {'id': 'place.7920357755186080',
#      'wikidata': 'Q1085611',
#      'text': 'Carneys Point'},
#     {'id': 'district.12142174298071680',
#      'wikidata': 'Q502587',
#      'text': 'Salem County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'poi.335007456105',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 0.74,
#    'properties': {'foursquare': '4e03a4d981dc9d212d0ffc6d',
#     'landmark': True,
#     'address': '199 E Broadway',
#     'category': 'government agency, office'},
#    'text': 'NJ Motor Vehicle Commission',
#    'place_name': 'NJ Motor Vehicle Commission, 199 E Broadway, Salem, New Jersey 08079, United States',
#    'center': [-75.466721, 39.571661],
#    'geometry': {'coordinates': [-75.466721, 39.571661], 'type': 'Point'},
#    'context': [{'id': 'postcode.15469193486410310', 'text': '08079'},
#     {'id': 'place.13682825831071680', 'wikidata': 'Q1088317', 'text': 'Salem'},
#     {'id': 'district.12142174298071680',
#      'wikidata': 'Q502587',
#      'text': 'Salem County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'poi.1099511680206',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 0.74,
#    'properties': {'foursquare': '4d7cb0d0136bf04dc57e638d',
#     'landmark': True,
#     'address': 'Interchange One',
#     'category': 'business, service, office'},
#    'text': 'NJ Turnpike Plaza Sergeants Office',
#    'place_name': 'NJ Turnpike Plaza Sergeants Office, Interchange One, Carneys Point, New Jersey 08069, United States',
#    'center': [-75.447551, 39.686216],
#    'geometry': {'coordinates': [-75.447551, 39.686216], 'type': 'Point'},
#    'context': [{'id': 'neighborhood.16849788063142460',
#      'text': 'Danceys Corner'},
#     {'id': 'postcode.6047690026045290', 'text': '08069'},
#     {'id': 'place.7920357755186080',
#      'wikidata': 'Q1085611',
#      'text': 'Carneys Point'},
#     {'id': 'district.12142174298071680',
#      'wikidata': 'Q502587',
#      'text': 'Salem County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'poi.695784751684',
#    'type': 'Feature',
#    'place_type': ['poi'],
#    'relevance': 0.74,
#    'properties': {'foursquare': '4c81c7c1dc018cfa0f8cc96c',
#     'landmark': True,
#     'address': 'Main St',
#     'category': 'rail station, train station',
#     'maki': 'rail'},
#    'text': 'NJT - Gladstone Station (M&E)',
#    'place_name': 'NJT - Gladstone Station (M&E), Main St, Gladstone, New Jersey 07934, United States',
#    'center': [-74.666049, 40.720148],
#    'geometry': {'coordinates': [-74.666049, 40.720148], 'type': 'Point'},
#    'context': [{'id': 'postcode.17815798881214310', 'text': '07934'},
#     {'id': 'locality.10875181339656640', 'text': 'Peapack and Gladstone'},
#     {'id': 'place.10930099337178620',
#      'wikidata': 'Q3476628',
#      'text': 'Gladstone'},
#     {'id': 'district.9962732021837830',
#      'wikidata': 'Q502414',
#      'text': 'Somerset County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %%
response = geocoder.reverse(lon=-74.7083, lat=40.7851)
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'query': [-74.7083, 40.7851],
#  'features': [{'id': 'address.1598740270488510',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'rooftop'},
#    'text': 'Mill Ridge Lane',
#    'place_name': '24 Mill Ridge Lane, Chester, New Jersey 07930, United States',
#    'center': [-74.70601, 40.78614],
#    'geometry': {'type': 'Point', 'coordinates': [-74.70601, 40.78614]},
#    'address': '24',
#    'context': [{'id': 'neighborhood.18099598004235870', 'text': 'Milltown'},
#     {'id': 'postcode.18500963620593220', 'text': '07930'},
#     {'id': 'place.2231300684375880',
#      'wikidata': 'Q3014459',
#      'text': 'Chester'},
#     {'id': 'district.15641134561761970',
#      'wikidata': 'Q498163',
#      'text': 'Morris County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'neighborhood.18099598004235870',
#    'type': 'Feature',
#    'place_type': ['neighborhood'],
#    'relevance': 1,
#    'properties': {},
#    'text': 'Milltown',
#    'place_name': 'Milltown, Chester, New Jersey, United States',
#    'bbox': [-74.741750488, 40.768461608, -74.68329834, 40.796780381],
#    'center': [-74.7204, 40.7798],
#    'geometry': {'type': 'Point', 'coordinates': [-74.7204, 40.7798]},
#    'context': [{'id': 'postcode.18500963620593220', 'text': '07930'},
#     {'id': 'place.2231300684375880',
#      'wikidata': 'Q3014459',
#      'text': 'Chester'},
#     {'id': 'district.15641134561761970',
#      'wikidata': 'Q498163',
#      'text': 'Morris County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'postcode.18500963620593220',
#    'type': 'Feature',
#    'place_type': ['postcode'],
#    'relevance': 1,
#    'properties': {},
#    'text': '07930',
#    'place_name': 'Chester, New Jersey 07930, United States',
#    'bbox': [-74.740621, 40.719531, -74.623719059, 40.834585976],
#    'center': [-74.69, 40.78],
#    'geometry': {'type': 'Point', 'coordinates': [-74.69, 40.78]},
#    'context': [{'id': 'place.2231300684375880',
#      'wikidata': 'Q3014459',
#      'text': 'Chester'},
#     {'id': 'district.15641134561761970',
#      'wikidata': 'Q498163',
#      'text': 'Morris County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'place.2231300684375880',
#    'type': 'Feature',
#    'place_type': ['place'],
#    'relevance': 1,
#    'properties': {'wikidata': 'Q3014459'},
#    'text': 'Chester',
#    'place_name': 'Chester, New Jersey, United States',
#    'bbox': [-74.740621662, 40.732998091, -74.623717003, 40.834595959],
#    'center': [-74.6968, 40.7843],
#    'geometry': {'type': 'Point', 'coordinates': [-74.6968, 40.7843]},
#    'context': [{'id': 'district.15641134561761970',
#      'wikidata': 'Q498163',
#      'text': 'Morris County'},
#     {'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'district.15641134561761970',
#    'type': 'Feature',
#    'place_type': ['district'],
#    'relevance': 1,
#    'properties': {'wikidata': 'Q498163'},
#    'text': 'Morris County',
#    'place_name': 'Morris County, New Jersey, United States',
#    'bbox': [-74.889819, 40.648447, -74.266597, 41.086114],
#    'center': [-74.55, 40.87],
#    'geometry': {'type': 'Point', 'coordinates': [-74.55, 40.87]},
#    'context': [{'id': 'region.8524001885700330',
#      'short_code': 'US-NJ',
#      'wikidata': 'Q1408',
#      'text': 'New Jersey'},
#     {'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'region.8524001885700330',
#    'type': 'Feature',
#    'place_type': ['region'],
#    'relevance': 1,
#    'properties': {'short_code': 'US-NJ', 'wikidata': 'Q1408'},
#    'text': 'New Jersey',
#    'place_name': 'New Jersey, United States',
#    'bbox': [-75.5741859892775,
#     38.8516494003392,
#     -73.8722201035284,
#     41.3574239900958],
#    'center': [-74.3893168105238, 40.1502478924],
#    'geometry': {'type': 'Point',
#     'coordinates': [-74.3893168105238, 40.1502478924]},
#    'context': [{'id': 'country.19678805456372290',
#      'wikidata': 'Q30',
#      'short_code': 'us',
#      'text': 'United States'}]},
#   {'id': 'country.19678805456372290',
#    'type': 'Feature',
#    'place_type': ['country'],
#    'relevance': 1,
#    'properties': {'wikidata': 'Q30', 'short_code': 'us'},
#    'text': 'United States',
#    'place_name': 'United States',
#    'bbox': [-179.9, 18.8163608007951, -66.8847646185949, 71.4202919997506],
#    'center': [-97.9222112121185, 39.3812661305678],
#    'geometry': {'type': 'Point',
#     'coordinates': [-97.9222112121185, 39.3812661305678]}}],
#  'attribution': 'NOTICE: © 2022 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}
