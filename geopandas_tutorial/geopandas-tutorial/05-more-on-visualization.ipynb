# %% [markdown]
# # Visualizing spatial data with Python

# %%
# %matplotlib inline

import pandas as pd
import geopandas

import matplotlib.pyplot as plt

# %%
countries = geopandas.read_file("zip://./data/ne_110m_admin_0_countries.zip")
cities = geopandas.read_file("zip://./data/ne_110m_populated_places.zip")
rivers = geopandas.read_file("zip://./data/ne_50m_rivers_lake_centerlines.zip")

# %% [markdown]
# ## GeoPandas visualization functionality

# %% [markdown]
# #### Basic plot

# %%
countries.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Adjusting the figure size

# %%
countries.plot(figsize=(15, 15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Removing the box / x and y coordinate labels

# %%
ax = countries.plot(figsize=(15, 15))
ax.set_axis_off()

# %% [markdown]
# #### Coloring based on column values
#
# Let's first create a new column with the GDP per capita:

# %%
countries = countries[(countries['pop_est'] >0 ) & (countries['name'] != "Antarctica")]

# %%
countries['gdp_per_cap'] = countries['gdp_md_est'] / countries['pop_est'] * 100
# Out:
# /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %% [markdown]
# and now we can use this column to color the polygons:

# %%
ax = countries.plot(figsize=(15, 15), column='gdp_per_cap')
ax.set_axis_off()

# %%
ax = countries.plot(figsize=(15, 15), column='gdp_per_cap', legend=True)
ax.set_axis_off()

# %% [markdown]
# #### Combining different dataframes on a single plot
#
# The `.plot` method returns a matplotlib Axes object, which can then be re-used to add additional layers to that plot with the `ax=` keyword:

# %%
ax = countries.plot(figsize=(15, 15))
cities.plot(ax=ax, color='red', markersize=10)
ax.set_axis_off()

# %%
ax = countries.plot(edgecolor='k', facecolor='none', figsize=(15, 10))
rivers.plot(ax=ax)
cities.plot(ax=ax, color='C1')
ax.set(xlim=(-20, 60), ylim=(-40, 40))
# Out:
# [(-20.0, 60.0), (-40.0, 40.0)]

# %% [markdown]
# ## Adding a background map with contextily

# %% [markdown]
# The contextily package allow to easily add a web-tile based backgroubd (basemap) to your GeoPandas plots.
#
# Currently, the only requirement is that your data is already in the WebMercator projection (EPSG:3857).

# %%
# selecting the cities in Europe
cities_europe = cities[cities.within(countries[countries['continent'] == 'Europe'].unary_union)]

# %%
# converting to WebMercator
cities_europe2 = cities_europe.to_crs(epsg=3857)

# %%
ax = cities_europe2.plot()

# %%
import contextily

# %%
ax = cities_europe2.plot(figsize=(10, 6))
contextily.add_basemap(ax)

# %%
ax = cities_europe2.plot(figsize=(10, 6))
contextily.add_basemap(ax, url=contextily.providers.Stamen.TonerLite)

# %% [markdown]
# ## Using `geoplot`
#
# The `geoplot` packages provides some additional functionality compared to the basic `.plot()` method on GeoDataFrames:
#
# - High-level plotting API (with more plot types as geopandas)
# - Native projection support through cartopy
#
# https://residentmario.github.io/geoplot/index.html

# %%
import geoplot
import geoplot.crs as gcrs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/p4/bklxjxxj2sq59w13x2tmsz9h0000gn/T/ipykernel_22780/2052158524.py in <module>
# ----> 1 import geoplot
#       2 import geoplot.crs as gcrs
#
# ModuleNotFoundError: No module named 'geoplot'

# %%
! pip install geoplot
# Out:
# Collecting geoplot
#   Using cached geoplot-0.5.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: contextily>=1.0.0 in /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages (from geoplot) (1.2.0)
# Requirement already satisfied: pandas in /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages (from geoplot) (1.3.5)
# Requirement already satisfied: matplotlib>=3.1.2 in /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages (from geoplot) (3.5.0)
# Requirement already satisfied: geopandas>=0.9.0 in /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages (from geoplot) (0.10.2)
# Requirement already satisfied: seaborn in /Users/simonxu/opt/anaconda3/lib/python3.8/site-packages (from geoplot) (0.11.2)
# Collecting cartopy
#   Using cached Cartopy-0.20.2.tar.gz (10.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [3 lines of output]
#       setup.py:117: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#         warnings.warn(
#       Proj 8.0.0 must be installed.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={
    'projection': gcrs.Orthographic(central_latitude=40.7128, central_longitude=-74.0059)
})
geoplot.choropleth(countries, hue='gdp_per_cap', projection=gcrs.Orthographic(), ax=ax,
                   cmap='magma', linewidth=0.5, edgecolor='white')
ax.set_global()
ax.outline_patch.set_visible(True)
#ax.coastlines()

# %% [markdown]
# ## Using `cartopy`
#
# Cartopy is the base matplotlib cartographic library, and it is used by `geoplot` under the hood to provide projection-awareness.
#
# http://scitools.org.uk/cartopy/docs/latest/index.html
#
# The following example is taken from the docs: http://geopandas.readthedocs.io/en/latest/gallery/cartopy_convert.html#sphx-glr-gallery-cartopy-convert-py

# %%
from cartopy import crs as ccrs

# %%
# Define the CartoPy CRS object.
crs = ccrs.AlbersEqualArea()

# This can be converted into a `proj4` string/dict compatible with GeoPandas
crs_proj4 = crs.proj4_init
countries_ae = countries.to_crs(crs_proj4)

# %%
# Here's what the plot looks like in GeoPandas
countries_ae.plot()

# %%
# Here's what the plot looks like when plotting with cartopy
fig, ax = plt.subplots(subplot_kw={'projection': crs})
ax.add_geometries(countries_ae['geometry'], crs=crs)

# %%
# Here's what the plot looks like when plotting with cartopy and geopandas combined
fig, ax = plt.subplots(subplot_kw={'projection': crs})
countries_ae['geometry'].plot(ax=ax)

# %% [markdown]
# ## Interactive web-based visualizations
#
# There are nowadays many libraries that target interactive web-based visualizations and that can handle geospatial data. Some packages with an example for each:
#
# - Bokeh: https://bokeh.pydata.org/en/latest/docs/gallery/texas.html
# - GeoViews (other interface to Bokeh/matplotlib): http://geo.holoviews.org
# - Altair: https://altair-viz.github.io/gallery/choropleth.html
# - Plotly: https://plot.ly/python/#maps
# - ...

# %% [markdown]
# Another popular javascript library for online maps is [Leaflet.js](https://leafletjs.com/), and this has python bindings in the [folium](https://github.com/python-visualization/folium) and [ipyleaflet](https://github.com/jupyter-widgets/ipyleaflet) packages.

# %% [markdown]
# An example with ipyleaflet:

# %%
import ipyleaflet

# %%
cities.__geo_interface__
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'id': '0',
#    'type': 'Feature',
#    'properties': {'name': 'Vatican City'},
#    'geometry': {'type': 'Point',
#     'coordinates': (12.453386544971766, 41.903282179960115)},
#    'bbox': (12.453386544971766,
#     41.903282179960115,
#     12.453386544971766,
#     41.903282179960115)},
#   {'id': '1',
#    'type': 'Feature',
#    'properties': {'name': 'San Marino'},
#    'geometry': {'type': 'Point',
#     'coordinates': (12.441770157800141, 43.936095834768004)},
#    'bbox': (12.441770157800141,
#     43.936095834768004,
#     12.441770157800141,
#     43.936095834768004)},
#   {'id': '2',
#    'type': 'Feature',
#    'properties': {'name': 'Vaduz'},
#    'geometry': {'type': 'Point',
#     'coordinates': (9.516669472907267, 47.13372377429357)},
#    'bbox': (9.516669472907267,
#     47.13372377429357,
#     9.516669472907267,
#     47.13372377429357)},
#   {'id': '3',
#    'type': 'Feature',
#    'properties': {'name': 'Lobamba'},
#    'geometry': {'type': 'Point',
#     'coordinates': (31.19999710971274, -26.466667461352472)},
#    'bbox': (31.19999710971274,
#     -26.466667461352472,
#     31.19999710971274,
#     -26.466667461352472)},
#   {'id': '4',
#    'type': 'Feature',
#    'properties': {'name': 'Luxembourg'},
#    'geometry': {'type': 'Point',
#     'coordinates': (6.130002806227083, 49.611660379121076)},
#    'bbox': (6.130002806227083,
#     49.611660379121076,
#     6.130002806227083,
#     49.611660379121076)},
#   {'id': '5',
#    'type': 'Feature',
#    'properties': {'name': 'Palikir'},
#    'geometry': {'type': 'Point',
#     'coordinates': (158.1499743237623, 6.916643696007725)},
#    'bbox': (158.1499743237623,
#     6.916643696007725,
#     158.1499743237623,
#     6.916643696007725)},
#   {'id': '6',
#    'type': 'Feature',
#    'properties': {'name': 'Majuro'},
#    'geometry': {'type': 'Point',
#     'coordinates': (171.38000017574655, 7.103004311216239)},
#    'bbox': (171.38000017574655,
#     7.103004311216239,
#     171.38000017574655,
#     7.103004311216239)},
#   {'id': '7',
#    'type': 'Feature',
#    'properties': {'name': 'Funafuti'},
#    'geometry': {'type': 'Point',
#     'coordinates': (179.21664709402887, -8.516651999041073)},
#    'bbox': (179.21664709402887,
#     -8.516651999041073,
#     179.21664709402887,
#     -8.516651999041073)},
#   {'id': '8',
#    'type': 'Feature',
#    'properties': {'name': 'Melekeok'},
#    'geometry': {'type': 'Point',
#     'coordinates': (134.62654846699218, 7.487396172977981)},
#    'bbox': (134.62654846699218,
#     7.487396172977981,
#     134.62654846699218,
#     7.487396172977981)},
#   {'id': '9',
#    'type': 'Feature',
#    'properties': {'name': 'Bir Lehlou'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-9.652522218250112, 26.119166685993378)},
#    'bbox': (-9.652522218250112,
#     26.119166685993378,
#     -9.652522218250112,
#     26.119166685993378)},
#   {'id': '10',
#    'type': 'Feature',
#    'properties': {'name': 'Monaco'},
#    'geometry': {'type': 'Point',
#     'coordinates': (7.406913173465057, 43.73964568785249)},
#    'bbox': (7.406913173465057,
#     43.73964568785249,
#     7.406913173465057,
#     43.73964568785249)},
#   {'id': '11',
#    'type': 'Feature',
#    'properties': {'name': 'Tarawa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (173.01757082854942, 1.338187505624603)},
#    'bbox': (173.01757082854942,
#     1.338187505624603,
#     173.01757082854942,
#     1.338187505624603)},
#   {'id': '12',
#    'type': 'Feature',
#    'properties': {'name': 'Moroni'},
#    'geometry': {'type': 'Point',
#     'coordinates': (43.240244098693324, -11.70415769566847)},
#    'bbox': (43.240244098693324,
#     -11.70415769566847,
#     43.240244098693324,
#     -11.70415769566847)},
#   {'id': '13',
#    'type': 'Feature',
#    'properties': {'name': 'Andorra'},
#    'geometry': {'type': 'Point',
#     'coordinates': (1.5164859605055199, 42.5000014435459)},
#    'bbox': (1.5164859605055199,
#     42.5000014435459,
#     1.5164859605055199,
#     42.5000014435459)},
#   {'id': '14',
#    'type': 'Feature',
#    'properties': {'name': 'Port-of-Spain'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.51703088544974, 10.651997089577264)},
#    'bbox': (-61.51703088544974,
#     10.651997089577264,
#     -61.51703088544974,
#     10.651997089577264)},
#   {'id': '15',
#    'type': 'Feature',
#    'properties': {'name': 'Kigali'},
#    'geometry': {'type': 'Point',
#     'coordinates': (30.058585919064114, -1.9516442100632503)},
#    'bbox': (30.058585919064114,
#     -1.9516442100632503,
#     30.058585919064114,
#     -1.9516442100632503)},
#   {'id': '16',
#    'type': 'Feature',
#    'properties': {'name': 'Mbabane'},
#    'geometry': {'type': 'Point',
#     'coordinates': (31.133334512056365, -26.316650778409212)},
#    'bbox': (31.133334512056365,
#     -26.316650778409212,
#     31.133334512056365,
#     -26.316650778409212)},
#   {'id': '17',
#    'type': 'Feature',
#    'properties': {'name': 'Juba'},
#    'geometry': {'type': 'Point',
#     'coordinates': (31.580025592787308, 4.829975198277964)},
#    'bbox': (31.580025592787308,
#     4.829975198277964,
#     31.580025592787308,
#     4.829975198277964)},
#   {'id': '18',
#    'type': 'Feature',
#    'properties': {'name': 'The Hague'},
#    'geometry': {'type': 'Point',
#     'coordinates': (4.2699613023134475, 52.08003684397488)},
#    'bbox': (4.2699613023134475,
#     52.08003684397488,
#     4.2699613023134475,
#     52.08003684397488)},
#   {'id': '19',
#    'type': 'Feature',
#    'properties': {'name': 'Ljubljana'},
#    'geometry': {'type': 'Point',
#     'coordinates': (14.51496903347413, 46.0552883087945)},
#    'bbox': (14.51496903347413,
#     46.0552883087945,
#     14.51496903347413,
#     46.0552883087945)},
#   {'id': '20',
#    'type': 'Feature',
#    'properties': {'name': 'Bratislava'},
#    'geometry': {'type': 'Point',
#     'coordinates': (17.11698075223461, 48.15001832996171)},
#    'bbox': (17.11698075223461,
#     48.15001832996171,
#     17.11698075223461,
#     48.15001832996171)},
#   {'id': '21',
#    'type': 'Feature',
#    'properties': {'name': 'Doha'},
#    'geometry': {'type': 'Point',
#     'coordinates': (51.532967894299304, 25.286556008906587)},
#    'bbox': (51.532967894299304,
#     25.286556008906587,
#     51.532967894299304,
#     25.286556008906587)},
#   {'id': '22',
#    'type': 'Feature',
#    'properties': {'name': 'Podgorica'},
#    'geometry': {'type': 'Point',
#     'coordinates': (19.266306924118226, 42.465972512881706)},
#    'bbox': (19.266306924118226,
#     42.465972512881706,
#     19.266306924118226,
#     42.465972512881706)},
#   {'id': '23',
#    'type': 'Feature',
#    'properties': {'name': 'Sri Jawewardenepura Kotte'},
#    'geometry': {'type': 'Point',
#     'coordinates': (79.94999304089748, 6.900003884809621)},
#    'bbox': (79.94999304089748,
#     6.900003884809621,
#     79.94999304089748,
#     6.900003884809621)},
#   {'id': '24',
#    'type': 'Feature',
#    'properties': {'name': 'Baguio City'},
#    'geometry': {'type': 'Point',
#     'coordinates': (120.56994258533086, 16.42999066056393)},
#    'bbox': (120.56994258533086,
#     16.42999066056393,
#     120.56994258533086,
#     16.42999066056393)},
#   {'id': '25',
#    'type': 'Feature',
#    'properties': {'name': 'Dodoma'},
#    'geometry': {'type': 'Point',
#     'coordinates': (35.75000362014765, -6.183306051766181)},
#    'bbox': (35.75000362014765,
#     -6.183306051766181,
#     35.75000362014765,
#     -6.183306051766181)},
#   {'id': '26',
#    'type': 'Feature',
#    'properties': {'name': 'Bern'},
#    'geometry': {'type': 'Point',
#     'coordinates': (7.466975462482424, 46.91668275866772)},
#    'bbox': (7.466975462482424,
#     46.91668275866772,
#     7.466975462482424,
#     46.91668275866772)},
#   {'id': '27',
#    'type': 'Feature',
#    'properties': {'name': 'Laayoune'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-13.200005942222674, 27.14998231913546)},
#    'bbox': (-13.200005942222674,
#     27.14998231913546,
#     -13.200005942222674,
#     27.14998231913546)},
#   {'id': '28',
#    'type': 'Feature',
#    'properties': {'name': 'Pristina'},
#    'geometry': {'type': 'Point',
#     'coordinates': (21.165984251599866, 42.666709614119384)},
#    'bbox': (21.165984251599866,
#     42.666709614119384,
#     21.165984251599866,
#     42.666709614119384)},
#   {'id': '29',
#    'type': 'Feature',
#    'properties': {'name': 'Roseau'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.387012981803366, 15.301015644283325)},
#    'bbox': (-61.387012981803366,
#     15.301015644283325,
#     -61.387012981803366,
#     15.301015644283325)},
#   {'id': '30',
#    'type': 'Feature',
#    'properties': {'name': 'Djibouti'},
#    'geometry': {'type': 'Point',
#     'coordinates': (43.148001667052256, 11.595014464255485)},
#    'bbox': (43.148001667052256,
#     11.595014464255485,
#     43.148001667052256,
#     11.595014464255485)},
#   {'id': '31',
#    'type': 'Feature',
#    'properties': {'name': 'Putrajaya'},
#    'geometry': {'type': 'Point',
#     'coordinates': (101.7019469797865, 2.9140197946245507)},
#    'bbox': (101.7019469797865,
#     2.9140197946245507,
#     101.7019469797865,
#     2.9140197946245507)},
#   {'id': '32',
#    'type': 'Feature',
#    'properties': {'name': 'Kyoto'},
#    'geometry': {'type': 'Point',
#     'coordinates': (135.7480520653204, 35.03193814685562)},
#    'bbox': (135.7480520653204,
#     35.03193814685562,
#     135.7480520653204,
#     35.03193814685562)},
#   {'id': '33',
#    'type': 'Feature',
#    'properties': {'name': 'Banjul'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-16.591701489212596, 13.45387646031594)},
#    'bbox': (-16.591701489212596,
#     13.45387646031594,
#     -16.591701489212596,
#     13.45387646031594)},
#   {'id': '34',
#    'type': 'Feature',
#    'properties': {'name': 'Skopje'},
#    'geometry': {'type': 'Point',
#     'coordinates': (21.4334614651425, 42.00000612290586)},
#    'bbox': (21.4334614651425,
#     42.00000612290586,
#     21.4334614651425,
#     42.00000612290586)},
#   {'id': '35',
#    'type': 'Feature',
#    'properties': {'name': 'Bridgetown'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-59.61652673505159, 13.10200258275114)},
#    'bbox': (-59.61652673505159,
#     13.10200258275114,
#     -59.61652673505159,
#     13.10200258275114)},
#   {'id': '36',
#    'type': 'Feature',
#    'properties': {'name': 'Porto-Novo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (2.61662552756718, 6.483310973024231)},
#    'bbox': (2.61662552756718,
#     6.483310973024231,
#     2.61662552756718,
#     6.483310973024231)},
#   {'id': '37',
#    'type': 'Feature',
#    'properties': {'name': 'Bujumbura'},
#    'geometry': {'type': 'Point',
#     'coordinates': (29.360006061528395, -3.376087220374643)},
#    'bbox': (29.360006061528395,
#     -3.376087220374643,
#     29.360006061528395,
#     -3.376087220374643)},
#   {'id': '38',
#    'type': 'Feature',
#    'properties': {'name': 'Kingstown'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.212062420279324, 13.14827882786841)},
#    'bbox': (-61.212062420279324,
#     13.14827882786841,
#     -61.212062420279324,
#     13.14827882786841)},
#   {'id': '39',
#    'type': 'Feature',
#    'properties': {'name': 'Castries'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.00000818036955, 14.00197348933034)},
#    'bbox': (-61.00000818036955,
#     14.00197348933034,
#     -61.00000818036955,
#     14.00197348933034)},
#   {'id': '40',
#    'type': 'Feature',
#    'properties': {'name': 'Basseterre'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-62.71700931969934, 17.302030455489387)},
#    'bbox': (-62.71700931969934,
#     17.302030455489387,
#     -62.71700931969934,
#     17.302030455489387)},
#   {'id': '41',
#    'type': 'Feature',
#    'properties': {'name': 'Port Louis'},
#    'geometry': {'type': 'Point',
#     'coordinates': (57.49999385460973, -20.166638571353246)},
#    'bbox': (57.49999385460973,
#     -20.166638571353246,
#     57.49999385460973,
#     -20.166638571353246)},
#   {'id': '42',
#    'type': 'Feature',
#    'properties': {'name': "Saint George's"},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.74164322607476, 12.052633401720414)},
#    'bbox': (-61.74164322607476,
#     12.052633401720414,
#     -61.74164322607476,
#     12.052633401720414)},
#   {'id': '43',
#    'type': 'Feature',
#    'properties': {'name': 'Manama'},
#    'geometry': {'type': 'Point',
#     'coordinates': (50.58305171591019, 26.236136290485945)},
#    'bbox': (50.58305171591019,
#     26.236136290485945,
#     50.58305171591019,
#     26.236136290485945)},
#   {'id': '44',
#    'type': 'Feature',
#    'properties': {'name': "Saint John's"},
#    'geometry': {'type': 'Point',
#     'coordinates': (-61.85003381513866, 17.118036518314113)},
#    'bbox': (-61.85003381513866,
#     17.118036518314113,
#     -61.85003381513866,
#     17.118036518314113)},
#   {'id': '45',
#    'type': 'Feature',
#    'properties': {'name': 'Montevideo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-56.17299814703597, -34.856095707590725)},
#    'bbox': (-56.17299814703597,
#     -34.856095707590725,
#     -56.17299814703597,
#     -34.856095707590725)},
#   {'id': '46',
#    'type': 'Feature',
#    'properties': {'name': 'Lomé'},
#    'geometry': {'type': 'Point',
#     'coordinates': (1.22081126074562, 6.133882930268385)},
#    'bbox': (1.22081126074562,
#     6.133882930268385,
#     1.22081126074562,
#     6.133882930268385)},
#   {'id': '47',
#    'type': 'Feature',
#    'properties': {'name': 'Tunis'},
#    'geometry': {'type': 'Point',
#     'coordinates': (10.179678099212026, 36.80277813623144)},
#    'bbox': (10.179678099212026,
#     36.80277813623144,
#     10.179678099212026,
#     36.80277813623144)},
#   {'id': '48',
#    'type': 'Feature',
#    'properties': {'name': 'Abu Dhabi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (54.36659338259199, 24.466683572379907)},
#    'bbox': (54.36659338259199,
#     24.466683572379907,
#     54.36659338259199,
#     24.466683572379907)},
#   {'id': '49',
#    'type': 'Feature',
#    'properties': {'name': 'Ashgabat'},
#    'geometry': {'type': 'Point',
#     'coordinates': (58.38329911177465, 37.949994933110986)},
#    'bbox': (58.38329911177465,
#     37.949994933110986,
#     58.38329911177465,
#     37.949994933110986)},
#   {'id': '50',
#    'type': 'Feature',
#    'properties': {'name': 'Lusaka'},
#    'geometry': {'type': 'Point',
#     'coordinates': (28.28138173611427, -15.414698409335926)},
#    'bbox': (28.28138173611427,
#     -15.414698409335926,
#     28.28138173611427,
#     -15.414698409335926)},
#   {'id': '51',
#    'type': 'Feature',
#    'properties': {'name': 'Harare'},
#    'geometry': {'type': 'Point',
#     'coordinates': (31.042763572062825, -17.815843835777798)},
#    'bbox': (31.042763572062825,
#     -17.815843835777798,
#     31.042763572062825,
#     -17.815843835777798)},
#   {'id': '52',
#    'type': 'Feature',
#    'properties': {'name': 'Dili'},
#    'geometry': {'type': 'Point',
#     'coordinates': (125.57945593170507, -8.559388408546454)},
#    'bbox': (125.57945593170507,
#     -8.559388408546454,
#     125.57945593170507,
#     -8.559388408546454)},
#   {'id': '53',
#    'type': 'Feature',
#    'properties': {'name': 'Port Vila'},
#    'geometry': {'type': 'Point',
#     'coordinates': (168.31664058356864, -17.733350404025828)},
#    'bbox': (168.31664058356864,
#     -17.733350404025828,
#     168.31664058356864,
#     -17.733350404025828)},
#   {'id': '54',
#    'type': 'Feature',
#    'properties': {'name': 'Tegucigalpa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-87.2194751979415, 14.103990759076396)},
#    'bbox': (-87.2194751979415,
#     14.103990759076396,
#     -87.2194751979415,
#     14.103990759076396)},
#   {'id': '55',
#    'type': 'Feature',
#    'properties': {'name': 'Georgetown'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-58.167028647480606, 6.8019736927520285)},
#    'bbox': (-58.167028647480606,
#     6.8019736927520285,
#     -58.167028647480606,
#     6.8019736927520285)},
#   {'id': '56',
#    'type': 'Feature',
#    'properties': {'name': 'Reykjavík'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-21.950014487179544, 64.15002361973922)},
#    'bbox': (-21.950014487179544,
#     64.15002361973922,
#     -21.950014487179544,
#     64.15002361973922)},
#   {'id': '57',
#    'type': 'Feature',
#    'properties': {'name': 'Port-au-Prince'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-72.33798044690553, 18.54297045473237)},
#    'bbox': (-72.33798044690553,
#     18.54297045473237,
#     -72.33798044690553,
#     18.54297045473237)},
#   {'id': '58',
#    'type': 'Feature',
#    'properties': {'name': 'Kampala'},
#    'geometry': {'type': 'Point',
#     'coordinates': (32.581377667121046, 0.318604813383331)},
#    'bbox': (32.581377667121046,
#     0.318604813383331,
#     32.581377667121046,
#     0.318604813383331)},
#   {'id': '59',
#    'type': 'Feature',
#    'properties': {'name': 'Paramaribo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-55.16703088542437, 5.835030129922586)},
#    'bbox': (-55.16703088542437,
#     5.835030129922586,
#     -55.16703088542437,
#     5.835030129922586)},
#   {'id': '60',
#    'type': 'Feature',
#    'properties': {'name': 'Niamey'},
#    'geometry': {'type': 'Point',
#     'coordinates': (2.114710186530374, 13.51865181050647)},
#    'bbox': (2.114710186530374,
#     13.51865181050647,
#     2.114710186530374,
#     13.51865181050647)},
#   {'id': '61',
#    'type': 'Feature',
#    'properties': {'name': 'Dushanbe'},
#    'geometry': {'type': 'Point',
#     'coordinates': (68.77387935270173, 38.56003521631658)},
#    'bbox': (68.77387935270173,
#     38.56003521631658,
#     68.77387935270173,
#     38.56003521631658)},
#   {'id': '62',
#    'type': 'Feature',
#    'properties': {'name': 'Asunción'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-57.643451027901335, -25.294457117057675)},
#    'bbox': (-57.643451027901335,
#     -25.294457117057675,
#     -57.643451027901335,
#     -25.294457117057675)},
#   {'id': '63',
#    'type': 'Feature',
#    'properties': {'name': 'Managua'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-86.27043751890119, 12.154962438756115)},
#    'bbox': (-86.27043751890119,
#     12.154962438756115,
#     -86.27043751890119,
#     12.154962438756115)},
#   {'id': '64',
#    'type': 'Feature',
#    'properties': {'name': 'Freetown'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-13.236161599012746, 8.471957271098177)},
#    'bbox': (-13.236161599012746,
#     8.471957271098177,
#     -13.236161599012746,
#     8.471957271098177)},
#   {'id': '65',
#    'type': 'Feature',
#    'properties': {'name': 'Islamabad'},
#    'geometry': {'type': 'Point',
#     'coordinates': (73.16468862105955, 33.70194180895959)},
#    'bbox': (73.16468862105955,
#     33.70194180895959,
#     73.16468862105955,
#     33.70194180895959)},
#   {'id': '66',
#    'type': 'Feature',
#    'properties': {'name': 'Kathmandu'},
#    'geometry': {'type': 'Point',
#     'coordinates': (85.31469635222788, 27.718637772477223)},
#    'bbox': (85.31469635222788,
#     27.718637772477223,
#     85.31469635222788,
#     27.718637772477223)},
#   {'id': '67',
#    'type': 'Feature',
#    'properties': {'name': 'Bloemfontein'},
#    'geometry': {'type': 'Point',
#     'coordinates': (26.22991288117737, -29.119993877378704)},
#    'bbox': (26.22991288117737,
#     -29.119993877378704,
#     26.22991288117737,
#     -29.119993877378704)},
#   {'id': '68',
#    'type': 'Feature',
#    'properties': {'name': 'Pretoria'},
#    'geometry': {'type': 'Point',
#     'coordinates': (28.22748321723384, -25.704974695184433)},
#    'bbox': (28.22748321723384,
#     -25.704974695184433,
#     28.22748321723384,
#     -25.704974695184433)},
#   {'id': '69',
#    'type': 'Feature',
#    'properties': {'name': 'Port Moresby'},
#    'geometry': {'type': 'Point',
#     'coordinates': (147.19250362059358, -9.464707825867777)},
#    'bbox': (147.19250362059358,
#     -9.464707825867777,
#     147.19250362059358,
#     -9.464707825867777)},
#   {'id': '70',
#    'type': 'Feature',
#    'properties': {'name': 'Honiara'},
#    'geometry': {'type': 'Point',
#     'coordinates': (159.94976573360566, -9.437994295089595)},
#    'bbox': (159.94976573360566,
#     -9.437994295089595,
#     159.94976573360566,
#     -9.437994295089595)},
#   {'id': '71',
#    'type': 'Feature',
#    'properties': {'name': 'Panama City'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-79.53498301041077, 8.969963049094872)},
#    'bbox': (-79.53498301041077,
#     8.969963049094872,
#     -79.53498301041077,
#     8.969963049094872)},
#   {'id': '72',
#    'type': 'Feature',
#    'properties': {'name': 'Rabat'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-6.83640815612614, 34.02530731107282)},
#    'bbox': (-6.83640815612614,
#     34.02530731107282,
#     -6.83640815612614,
#     34.02530731107282)},
#   {'id': '73',
#    'type': 'Feature',
#    'properties': {'name': 'Chi?in?u'},
#    'geometry': {'type': 'Point',
#     'coordinates': (28.85771113965143, 47.005023619670624)},
#    'bbox': (28.85771113965143,
#     47.005023619670624,
#     28.85771113965143,
#     47.005023619670624)},
#   {'id': '74',
#    'type': 'Feature',
#    'properties': {'name': 'Maputo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (32.58721710397009, -25.953331628778983)},
#    'bbox': (32.58721710397009,
#     -25.953331628778983,
#     32.58721710397009,
#     -25.953331628778983)},
#   {'id': '75',
#    'type': 'Feature',
#    'properties': {'name': 'Mogadishu'},
#    'geometry': {'type': 'Point',
#     'coordinates': (45.36473175245874, 2.068627192947531)},
#    'bbox': (45.36473175245874,
#     2.068627192947531,
#     45.36473175245874,
#     2.068627192947531)},
#   {'id': '76',
#    'type': 'Feature',
#    'properties': {'name': 'Muscat'},
#    'geometry': {'type': 'Point',
#     'coordinates': (58.593312132608844, 23.613324807728134)},
#    'bbox': (58.593312132608844,
#     23.613324807728134,
#     58.593312132608844,
#     23.613324807728134)},
#   {'id': '77',
#    'type': 'Feature',
#    'properties': {'name': 'Colombo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (79.85775060925641, 6.931965758182116)},
#    'bbox': (79.85775060925641,
#     6.931965758182116,
#     79.85775060925641,
#     6.931965758182116)},
#   {'id': '78',
#    'type': 'Feature',
#    'properties': {'name': 'Ulaanbaatar'},
#    'geometry': {'type': 'Point',
#     'coordinates': (106.91466990374653, 47.91861925856074)},
#    'bbox': (106.91466990374653,
#     47.91861925856074,
#     106.91466990374653,
#     47.91861925856074)},
#   {'id': '79',
#    'type': 'Feature',
#    'properties': {'name': 'Windhoek'},
#    'geometry': {'type': 'Point',
#     'coordinates': (17.08354610054181, -22.570006084383806)},
#    'bbox': (17.08354610054181,
#     -22.570006084383806,
#     17.08354610054181,
#     -22.570006084383806)},
#   {'id': '80',
#    'type': 'Feature',
#    'properties': {'name': 'Abuja'},
#    'geometry': {'type': 'Point',
#     'coordinates': (7.53138214293233, 9.085279007754195)},
#    'bbox': (7.53138214293233,
#     9.085279007754195,
#     7.53138214293233,
#     9.085279007754195)},
#   {'id': '81',
#    'type': 'Feature',
#    'properties': {'name': 'Bissau'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-15.598360841320755, 11.865023822980561)},
#    'bbox': (-15.598360841320755,
#     11.865023822980561,
#     -15.598360841320755,
#     11.865023822980561)},
#   {'id': '82',
#    'type': 'Feature',
#    'properties': {'name': 'Amman'},
#    'geometry': {'type': 'Point',
#     'coordinates': (35.93135406687412, 31.951971105827454)},
#    'bbox': (35.93135406687412,
#     31.951971105827454,
#     35.93135406687412,
#     31.951971105827454)},
#   {'id': '83',
#    'type': 'Feature',
#    'properties': {'name': 'Vilnius'},
#    'geometry': {'type': 'Point',
#     'coordinates': (25.3166352932829, 54.68336631175862)},
#    'bbox': (25.3166352932829,
#     54.68336631175862,
#     25.3166352932829,
#     54.68336631175862)},
#   {'id': '84',
#    'type': 'Feature',
#    'properties': {'name': 'Riga'},
#    'geometry': {'type': 'Point',
#     'coordinates': (24.099965371403187, 56.95002382316096)},
#    'bbox': (24.099965371403187,
#     56.95002382316096,
#     24.099965371403187,
#     56.95002382316096)},
#   {'id': '85',
#    'type': 'Feature',
#    'properties': {'name': 'Bishkek'},
#    'geometry': {'type': 'Point',
#     'coordinates': (74.58325836390367, 42.875025305090105)},
#    'bbox': (74.58325836390367,
#     42.875025305090105,
#     74.58325836390367,
#     42.875025305090105)},
#   {'id': '86',
#    'type': 'Feature',
#    'properties': {'name': 'Maseru'},
#    'geometry': {'type': 'Point',
#     'coordinates': (27.483273069984477, -29.316674378681626)},
#    'bbox': (27.483273069984477,
#     -29.316674378681626,
#     27.483273069984477,
#     -29.316674378681626)},
#   {'id': '87',
#    'type': 'Feature',
#    'properties': {'name': 'Antananarivo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (47.51467804152986, -18.914691492032148)},
#    'bbox': (47.51467804152986,
#     -18.914691492032148,
#     47.51467804152986,
#     -18.914691492032148)},
#   {'id': '88',
#    'type': 'Feature',
#    'properties': {'name': 'Quito'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-78.5019969671124, -0.2130423220355624)},
#    'bbox': (-78.5019969671124,
#     -0.2130423220355624,
#     -78.5019969671124,
#     -0.2130423220355624)},
#   {'id': '89',
#    'type': 'Feature',
#    'properties': {'name': 'San José'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-84.08599721127536, 9.936958288356607)},
#    'bbox': (-84.08599721127536,
#     9.936958288356607,
#     -84.08599721127536,
#     9.936958288356607)},
#   {'id': '90',
#    'type': 'Feature',
#    'properties': {'name': 'San Salvador'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-89.2049870794599, 13.711947505494038)},
#    'bbox': (-89.2049870794599,
#     13.711947505494038,
#     -89.2049870794599,
#     13.711947505494038)},
#   {'id': '91',
#    'type': 'Feature',
#    'properties': {'name': 'Kingston'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-76.7674337136691, 17.977076623830897)},
#    'bbox': (-76.7674337136691,
#     17.977076623830897,
#     -76.7674337136691,
#     17.977076623830897)},
#   {'id': '92',
#    'type': 'Feature',
#    'properties': {'name': 'Ndjamena'},
#    'geometry': {'type': 'Point',
#     'coordinates': (15.047202455462298, 12.115042394810644)},
#    'bbox': (15.047202455462298,
#     12.115042394810644,
#     15.047202455462298,
#     12.115042394810644)},
#   {'id': '93',
#    'type': 'Feature',
#    'properties': {'name': 'Malabo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (8.783277545821136, 3.750015278026183)},
#    'bbox': (8.783277545821136,
#     3.750015278026183,
#     8.783277545821136,
#     3.750015278026183)},
#   {'id': '94',
#    'type': 'Feature',
#    'properties': {'name': 'Asmara'},
#    'geometry': {'type': 'Point',
#     'coordinates': (38.933323525759306, 15.333339252681924)},
#    'bbox': (38.933323525759306,
#     15.333339252681924,
#     38.933323525759306,
#     15.333339252681924)},
#   {'id': '95',
#    'type': 'Feature',
#    'properties': {'name': 'Zagreb'},
#    'geometry': {'type': 'Point',
#     'coordinates': (15.999994668245677, 45.80000673327254)},
#    'bbox': (15.999994668245677,
#     45.80000673327254,
#     15.999994668245677,
#     45.80000673327254)},
#   {'id': '96',
#    'type': 'Feature',
#    'properties': {'name': 'Tallinn'},
#    'geometry': {'type': 'Point',
#     'coordinates': (24.72804072947855, 59.43387737948592)},
#    'bbox': (24.72804072947855,
#     59.43387737948592,
#     24.72804072947855,
#     59.43387737948592)},
#   {'id': '97',
#    'type': 'Feature',
#    'properties': {'name': 'Lilongwe'},
#    'geometry': {'type': 'Point',
#     'coordinates': (33.78330195998353, -13.983295065469179)},
#    'bbox': (33.78330195998353,
#     -13.983295065469179,
#     33.78330195998353,
#     -13.983295065469179)},
#   {'id': '98',
#    'type': 'Feature',
#    'properties': {'name': 'Guatemala'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-90.52891143656154, 14.623080521448173)},
#    'bbox': (-90.52891143656154,
#     14.623080521448173,
#     -90.52891143656154,
#     14.623080521448173)},
#   {'id': '99',
#    'type': 'Feature',
#    'properties': {'name': 'Libreville'},
#    'geometry': {'type': 'Point',
#     'coordinates': (9.457965045823698, 0.3853886097185182)},
#    'bbox': (9.457965045823698,
#     0.3853886097185182,
#     9.457965045823698,
#     0.3853886097185182)},
#   {'id': '100',
#    'type': 'Feature',
#    'properties': {'name': 'Suva'},
#    'geometry': {'type': 'Point',
#     'coordinates': (178.44170731537986, -18.133015931371233)},
#    'bbox': (178.44170731537986,
#     -18.133015931371233,
#     178.44170731537986,
#     -18.133015931371233)},
#   {'id': '101',
#    'type': 'Feature',
#    'properties': {'name': 'Valparaíso'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-71.62295949149893, -33.045818607974184)},
#    'bbox': (-71.62295949149893,
#     -33.045818607974184,
#     -71.62295949149893,
#     -33.045818607974184)},
#   {'id': '102',
#    'type': 'Feature',
#    'properties': {'name': 'Nouakchott'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-15.975340414890013, 18.086427021247516)},
#    'bbox': (-15.975340414890013,
#     18.086427021247516,
#     -15.975340414890013,
#     18.086427021247516)},
#   {'id': '103',
#    'type': 'Feature',
#    'properties': {'name': 'Bamako'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-8.001984963249697, 12.65196052632325)},
#    'bbox': (-8.001984963249697,
#     12.65196052632325,
#     -8.001984963249697,
#     12.65196052632325)},
#   {'id': '104',
#    'type': 'Feature',
#    'properties': {'name': 'Beirut'},
#    'geometry': {'type': 'Point',
#     'coordinates': (35.507762351377664, 33.8739209756269)},
#    'bbox': (35.507762351377664,
#     33.8739209756269,
#     35.507762351377664,
#     33.8739209756269)},
#   {'id': '105',
#    'type': 'Feature',
#    'properties': {'name': 'Tbilisi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (44.788849590997984, 41.72695584707759)},
#    'bbox': (44.788849590997984,
#     41.72695584707759,
#     44.788849590997984,
#     41.72695584707759)},
#   {'id': '106',
#    'type': 'Feature',
#    'properties': {'name': 'Astana'},
#    'geometry': {'type': 'Point',
#     'coordinates': (71.427774209483, 51.18112530425759)},
#    'bbox': (71.427774209483,
#     51.18112530425759,
#     71.427774209483,
#     51.18112530425759)},
#   {'id': '107',
#    'type': 'Feature',
#    'properties': {'name': 'Vientiane'},
#    'geometry': {'type': 'Point',
#     'coordinates': (102.59998002015476, 17.96669272762739)},
#    'bbox': (102.59998002015476,
#     17.96669272762739,
#     102.59998002015476,
#     17.96669272762739)},
#   {'id': '108',
#    'type': 'Feature',
#    'properties': {'name': 'Brazzaville'},
#    'geometry': {'type': 'Point',
#     'coordinates': (15.282743633848668, -4.257239913197509)},
#    'bbox': (15.282743633848668,
#     -4.257239913197509,
#     15.282743633848668,
#     -4.257239913197509)},
#   {'id': '109',
#    'type': 'Feature',
#    'properties': {'name': 'Conakry'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-13.682180886123945, 9.53346870502179)},
#    'bbox': (-13.682180886123945,
#     9.53346870502179,
#     -13.682180886123945,
#     9.53346870502179)},
#   {'id': '110',
#    'type': 'Feature',
#    'properties': {'name': 'Yamoussoukro'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-5.275502564912301, 6.8183809600046175)},
#    'bbox': (-5.275502564912301,
#     6.8183809600046175,
#     -5.275502564912301,
#     6.8183809600046175)},
#   {'id': '111',
#    'type': 'Feature',
#    'properties': {'name': 'Ottawa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-75.70196115980951, 45.41864265536043)},
#    'bbox': (-75.70196115980951,
#     45.41864265536043,
#     -75.70196115980951,
#     45.41864265536043)},
#   {'id': '112',
#    'type': 'Feature',
#    'properties': {'name': 'Belgrade'},
#    'geometry': {'type': 'Point',
#     'coordinates': (20.466044822020535, 44.82059130444674)},
#    'bbox': (20.466044822020535,
#     44.82059130444674,
#     20.466044822020535,
#     44.82059130444674)},
#   {'id': '113',
#    'type': 'Feature',
#    'properties': {'name': 'Bandar Seri Begawan'},
#    'geometry': {'type': 'Point',
#     'coordinates': (114.93328405666227, 4.883331114619239)},
#    'bbox': (114.93328405666227,
#     4.883331114619239,
#     114.93328405666227,
#     4.883331114619239)},
#   {'id': '114',
#    'type': 'Feature',
#    'properties': {'name': 'Sucre'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-65.25951562667564, -19.04097084673947)},
#    'bbox': (-65.25951562667564,
#     -19.04097084673947,
#     -65.25951562667564,
#     -19.04097084673947)},
#   {'id': '115',
#    'type': 'Feature',
#    'properties': {'name': 'Belmopan'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-88.76707299981655, 17.252033507246892)},
#    'bbox': (-88.76707299981655,
#     17.252033507246892,
#     -88.76707299981655,
#     17.252033507246892)},
#   {'id': '116',
#    'type': 'Feature',
#    'properties': {'name': 'Bangui'},
#    'geometry': {'type': 'Point',
#     'coordinates': (18.558288125287277, 4.366644306349087)},
#    'bbox': (18.558288125287277,
#     4.366644306349087,
#     18.558288125287277,
#     4.366644306349087)},
#   {'id': '117',
#    'type': 'Feature',
#    'properties': {'name': 'Yaounde'},
#    'geometry': {'type': 'Point',
#     'coordinates': (11.514704896854425, 3.868646520754112)},
#    'bbox': (11.514704896854425,
#     3.868646520754112,
#     11.514704896854425,
#     3.868646520754112)},
#   {'id': '118',
#    'type': 'Feature',
#    'properties': {'name': 'Tirana'},
#    'geometry': {'type': 'Point',
#     'coordinates': (19.81888301461521, 41.327540709491586)},
#    'bbox': (19.81888301461521,
#     41.327540709491586,
#     19.81888301461521,
#     41.327540709491586)},
#   {'id': '119',
#    'type': 'Feature',
#    'properties': {'name': 'Yerevan'},
#    'geometry': {'type': 'Point',
#     'coordinates': (44.51160553175208, 40.18309659414189)},
#    'bbox': (44.51160553175208,
#     40.18309659414189,
#     44.51160553175208,
#     40.18309659414189)},
#   {'id': '120',
#    'type': 'Feature',
#    'properties': {'name': 'Baku'},
#    'geometry': {'type': 'Point',
#     'coordinates': (49.860271303257775, 40.39721789134302)},
#    'bbox': (49.860271303257775,
#     40.39721789134302,
#     49.860271303257775,
#     40.39721789134302)},
#   {'id': '121',
#    'type': 'Feature',
#    'properties': {'name': 'Phnom Penh'},
#    'geometry': {'type': 'Point',
#     'coordinates': (104.91468862118643, 11.55197598855841)},
#    'bbox': (104.91468862118643,
#     11.55197598855841,
#     104.91468862118643,
#     11.55197598855841)},
#   {'id': '122',
#    'type': 'Feature',
#    'properties': {'name': 'La Paz'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-68.15193104910219, -16.49602775504337)},
#    'bbox': (-68.15193104910219,
#     -16.49602775504337,
#     -68.15193104910219,
#     -16.49602775504337)},
#   {'id': '123',
#    'type': 'Feature',
#    'properties': {'name': 'Cotonou'},
#    'geometry': {'type': 'Point',
#     'coordinates': (2.518044740568598, 6.401954422782467)},
#    'bbox': (2.518044740568598,
#     6.401954422782467,
#     2.518044740568598,
#     6.401954422782467)},
#   {'id': '124',
#    'type': 'Feature',
#    'properties': {'name': 'Sofia'},
#    'geometry': {'type': 'Point',
#     'coordinates': (23.314708152110086, 42.68529528393054)},
#    'bbox': (23.314708152110086,
#     42.68529528393054,
#     23.314708152110086,
#     42.68529528393054)},
#   {'id': '125',
#    'type': 'Feature',
#    'properties': {'name': 'Minsk'},
#    'geometry': {'type': 'Point',
#     'coordinates': (27.56468129665825, 53.901923295043105)},
#    'bbox': (27.56468129665825,
#     53.901923295043105,
#     27.56468129665825,
#     53.901923295043105)},
#   {'id': '126',
#    'type': 'Feature',
#    'properties': {'name': 'Thimphu'},
#    'geometry': {'type': 'Point',
#     'coordinates': (89.63901403703, 27.472985859175765)},
#    'bbox': (89.63901403703,
#     27.472985859175765,
#     89.63901403703,
#     27.472985859175765)},
#   {'id': '127',
#    'type': 'Feature',
#    'properties': {'name': 'Gaborone'},
#    'geometry': {'type': 'Point',
#     'coordinates': (25.91194779328538, -24.646313457438907)},
#    'bbox': (25.91194779328538,
#     -24.646313457438907,
#     25.91194779328538,
#     -24.646313457438907)},
#   {'id': '128',
#    'type': 'Feature',
#    'properties': {'name': 'Canberra'},
#    'geometry': {'type': 'Point',
#     'coordinates': (149.1290262442992, -35.283028545372076)},
#    'bbox': (149.1290262442992,
#     -35.283028545372076,
#     149.1290262442992,
#     -35.283028545372076)},
#   {'id': '129',
#    'type': 'Feature',
#    'properties': {'name': 'Ouagadougou'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-1.5266696149164432, 12.372261836543373)},
#    'bbox': (-1.5266696149164432,
#     12.372261836543373,
#     -1.5266696149164432,
#     12.372261836543373)},
#   {'id': '130',
#    'type': 'Feature',
#    'properties': {'name': 'Sarajevo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (18.383001666953305, 43.850022398954934)},
#    'bbox': (18.383001666953305,
#     43.850022398954934,
#     18.383001666953305,
#     43.850022398954934)},
#   {'id': '131',
#    'type': 'Feature',
#    'properties': {'name': 'Naypyidaw'},
#    'geometry': {'type': 'Point',
#     'coordinates': (96.11667267063035, 19.76850288475015)},
#    'bbox': (96.11667267063035,
#     19.76850288475015,
#     96.11667267063035,
#     19.76850288475015)},
#   {'id': '132',
#    'type': 'Feature',
#    'properties': {'name': 'Nukualofa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-175.22056447761656, -21.13851235669864)},
#    'bbox': (-175.22056447761656,
#     -21.13851235669864,
#     -175.22056447761656,
#     -21.13851235669864)},
#   {'id': '133',
#    'type': 'Feature',
#    'properties': {'name': 'Hargeysa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (44.06531001666542, 9.56002239881775)},
#    'bbox': (44.06531001666542,
#     9.56002239881775,
#     44.06531001666542,
#     9.56002239881775)},
#   {'id': '134',
#    'type': 'Feature',
#    'properties': {'name': 'Victoria'},
#    'geometry': {'type': 'Point',
#     'coordinates': (55.44998978559113, -4.6166316539734)},
#    'bbox': (55.44998978559113,
#     -4.6166316539734,
#     55.44998978559113,
#     -4.6166316539734)},
#   {'id': '135',
#    'type': 'Feature',
#    'properties': {'name': 'São Tomé'},
#    'geometry': {'type': 'Point',
#     'coordinates': (6.733325153234773, 0.3334021188329075)},
#    'bbox': (6.733325153234773,
#     0.3334021188329075,
#     6.733325153234773,
#     0.3334021188329075)},
#   {'id': '136',
#    'type': 'Feature',
#    'properties': {'name': 'Apia'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-171.73864160860316, -13.841545042448445)},
#    'bbox': (-171.73864160860316,
#     -13.841545042448445,
#     -171.73864160860316,
#     -13.841545042448445)},
#   {'id': '137',
#    'type': 'Feature',
#    'properties': {'name': 'Valletta'},
#    'geometry': {'type': 'Point',
#     'coordinates': (14.514710651312782, 35.89973248193087)},
#    'bbox': (14.514710651312782,
#     35.89973248193087,
#     14.514710651312782,
#     35.89973248193087)},
#   {'id': '138',
#    'type': 'Feature',
#    'properties': {'name': 'Malé'},
#    'geometry': {'type': 'Point',
#     'coordinates': (73.499947467955, 4.1667081898118)},
#    'bbox': (73.499947467955,
#     4.1667081898118,
#     73.499947467955,
#     4.1667081898118)},
#   {'id': '139',
#    'type': 'Feature',
#    'properties': {'name': 'Jerusalem'},
#    'geometry': {'type': 'Point',
#     'coordinates': (35.20662593459866, 31.778407815573303)},
#    'bbox': (35.20662593459866,
#     31.778407815573303,
#     35.20662593459866,
#     31.778407815573303)},
#   {'id': '140',
#    'type': 'Feature',
#    'properties': {'name': 'Praia'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-23.51668888497221, 14.916698017328656)},
#    'bbox': (-23.51668888497221,
#     14.916698017328656,
#     -23.51668888497221,
#     14.916698017328656)},
#   {'id': '141',
#    'type': 'Feature',
#    'properties': {'name': 'Nassau'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-77.35004378427612, 25.08339011535122)},
#    'bbox': (-77.35004378427612,
#     25.08339011535122,
#     -77.35004378427612,
#     25.08339011535122)},
#   {'id': '142',
#    'type': 'Feature',
#    'properties': {'name': 'Nicosia'},
#    'geometry': {'type': 'Point',
#     'coordinates': (33.36663488641415, 35.166676451654496)},
#    'bbox': (33.36663488641415,
#     35.166676451654496,
#     33.36663488641415,
#     35.166676451654496)},
#   {'id': '143',
#    'type': 'Feature',
#    'properties': {'name': 'Wellington'},
#    'geometry': {'type': 'Point',
#     'coordinates': (174.7832658592819, -41.29998785369173)},
#    'bbox': (174.7832658592819,
#     -41.29998785369173,
#     174.7832658592819,
#     -41.29998785369173)},
#   {'id': '144',
#    'type': 'Feature',
#    'properties': {'name': 'Hanoi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (105.8480683412422, 21.035273107737055)},
#    'bbox': (105.8480683412422,
#     21.035273107737055,
#     105.8480683412422,
#     21.035273107737055)},
#   {'id': '145',
#    'type': 'Feature',
#    'properties': {'name': 'Ankara'},
#    'geometry': {'type': 'Point',
#     'coordinates': (32.862445782356644, 39.929184444075474)},
#    'bbox': (32.862445782356644,
#     39.929184444075474,
#     32.862445782356644,
#     39.929184444075474)},
#   {'id': '146',
#    'type': 'Feature',
#    'properties': {'name': 'Budapest'},
#    'geometry': {'type': 'Point',
#     'coordinates': (19.081374818759684, 47.50195218499135)},
#    'bbox': (19.081374818759684,
#     47.50195218499135,
#     19.081374818759684,
#     47.50195218499135)},
#   {'id': '147',
#    'type': 'Feature',
#    'properties': {'name': 'Sanaa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (44.20464752393843, 15.356679154263645)},
#    'bbox': (44.20464752393843,
#     15.356679154263645,
#     44.20464752393843,
#     15.356679154263645)},
#   {'id': '148',
#    'type': 'Feature',
#    'properties': {'name': 'Bucharest'},
#    'geometry': {'type': 'Point',
#     'coordinates': (26.0980007953504, 44.43531766349457)},
#    'bbox': (26.0980007953504,
#     44.43531766349457,
#     26.0980007953504,
#     44.43531766349457)},
#   {'id': '149',
#    'type': 'Feature',
#    'properties': {'name': 'Damascus'},
#    'geometry': {'type': 'Point',
#     'coordinates': (36.29805003041707, 33.50197985420613)},
#    'bbox': (36.29805003041707,
#     33.50197985420613,
#     36.29805003041707,
#     33.50197985420613)},
#   {'id': '150',
#    'type': 'Feature',
#    'properties': {'name': 'Lisbon'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-9.14681216410213, 38.72466873648784)},
#    'bbox': (-9.14681216410213,
#     38.72466873648784,
#     -9.14681216410213,
#     38.72466873648784)},
#   {'id': '151',
#    'type': 'Feature',
#    'properties': {'name': 'Khartoum'},
#    'geometry': {'type': 'Point',
#     'coordinates': (32.532233380011576, 15.590024084277673)},
#    'bbox': (32.532233380011576,
#     15.590024084277673,
#     32.532233380011576,
#     15.590024084277673)},
#   {'id': '152',
#    'type': 'Feature',
#    'properties': {'name': 'Oslo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (10.748033347372314, 59.91863614500187)},
#    'bbox': (10.748033347372314,
#     59.91863614500187,
#     10.748033347372314,
#     59.91863614500187)},
#   {'id': '153',
#    'type': 'Feature',
#    'properties': {'name': 'Warsaw'},
#    'geometry': {'type': 'Point',
#     'coordinates': (20.998053692465305, 52.25194648839556)},
#    'bbox': (20.998053692465305,
#     52.25194648839556,
#     20.998053692465305,
#     52.25194648839556)},
#   {'id': '154',
#    'type': 'Feature',
#    'properties': {'name': 'Pyongyang'},
#    'geometry': {'type': 'Point',
#     'coordinates': (125.75274485499392, 39.02138455800434)},
#    'bbox': (125.75274485499392,
#     39.02138455800434,
#     125.75274485499392,
#     39.02138455800434)},
#   {'id': '155',
#    'type': 'Feature',
#    'properties': {'name': 'Dar es Salaam'},
#    'geometry': {'type': 'Point',
#     'coordinates': (39.26639597769457, -6.798066736124383)},
#    'bbox': (39.26639597769457,
#     -6.798066736124383,
#     39.26639597769457,
#     -6.798066736124383)},
#   {'id': '156',
#    'type': 'Feature',
#    'properties': {'name': 'Dublin'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-6.250851540391068, 53.335006994584944)},
#    'bbox': (-6.250851540391068,
#     53.335006994584944,
#     -6.250851540391068,
#     53.335006994584944)},
#   {'id': '157',
#    'type': 'Feature',
#    'properties': {'name': 'Monrovia'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-10.799660436775923, 6.314581647160139)},
#    'bbox': (-10.799660436775923,
#     6.314581647160139,
#     -10.799660436775923,
#     6.314581647160139)},
#   {'id': '158',
#    'type': 'Feature',
#    'properties': {'name': 'Kuala Lumpur'},
#    'geometry': {'type': 'Point',
#     'coordinates': (101.69803741674644, 3.168611730712371)},
#    'bbox': (101.69803741674644,
#     3.168611730712371,
#     101.69803741674644,
#     3.168611730712371)},
#   {'id': '159',
#    'type': 'Feature',
#    'properties': {'name': 'Havana'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-82.3661280299533, 23.1339046995422)},
#    'bbox': (-82.3661280299533,
#     23.1339046995422,
#     -82.3661280299533,
#     23.1339046995422)},
#   {'id': '160',
#    'type': 'Feature',
#    'properties': {'name': 'Prague'},
#    'geometry': {'type': 'Point',
#     'coordinates': (14.464033917048539, 50.08528287347832)},
#    'bbox': (14.464033917048539,
#     50.08528287347832,
#     14.464033917048539,
#     50.08528287347832)},
#   {'id': '161',
#    'type': 'Feature',
#    'properties': {'name': 'Kuwait'},
#    'geometry': {'type': 'Point',
#     'coordinates': (47.97635528762527, 29.371663488629565)},
#    'bbox': (47.97635528762527,
#     29.371663488629565,
#     47.97635528762527,
#     29.371663488629565)},
#   {'id': '162',
#    'type': 'Feature',
#    'properties': {'name': 'Santo Domingo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-69.90203094331503, 18.472018713195382)},
#    'bbox': (-69.90203094331503,
#     18.472018713195382,
#     -69.90203094331503,
#     18.472018713195382)},
#   {'id': '163',
#    'type': 'Feature',
#    'properties': {'name': 'Accra'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-0.21866159896069348, 5.551980464445933)},
#    'bbox': (-0.21866159896069348,
#     5.551980464445933,
#     -0.21866159896069348,
#     5.551980464445933)},
#   {'id': '164',
#    'type': 'Feature',
#    'properties': {'name': 'Tripoli'},
#    'geometry': {'type': 'Point',
#     'coordinates': (13.180011758078194, 32.89250001935369)},
#    'bbox': (13.180011758078194,
#     32.89250001935369,
#     13.180011758078194,
#     32.89250001935369)},
#   {'id': '165',
#    'type': 'Feature',
#    'properties': {'name': 'Tel Aviv-Yafo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (34.76806589955174, 32.08193733304165)},
#    'bbox': (34.76806589955174,
#     32.08193733304165,
#     34.76806589955174,
#     32.08193733304165)},
#   {'id': '166',
#    'type': 'Feature',
#    'properties': {'name': 'Helsinki'},
#    'geometry': {'type': 'Point',
#     'coordinates': (24.93218048284558, 60.17750923256807)},
#    'bbox': (24.93218048284558,
#     60.17750923256807,
#     24.93218048284558,
#     60.17750923256807)},
#   {'id': '167',
#    'type': 'Feature',
#    'properties': {'name': 'København'},
#    'geometry': {'type': 'Point',
#     'coordinates': (12.561539888703294, 55.68051004902594)},
#    'bbox': (12.561539888703294,
#     55.68051004902594,
#     12.561539888703294,
#     55.68051004902594)},
#   {'id': '168',
#    'type': 'Feature',
#    'properties': {'name': 'Abidjan'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-4.041994118507091, 5.321942826098564)},
#    'bbox': (-4.041994118507091,
#     5.321942826098564,
#     -4.041994118507091,
#     5.321942826098564)},
#   {'id': '169',
#    'type': 'Feature',
#    'properties': {'name': 'Brasília'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-47.91799814700306, -15.781394372878992)},
#    'bbox': (-47.91799814700306,
#     -15.781394372878992,
#     -47.91799814700306,
#     -15.781394372878992)},
#   {'id': '170',
#    'type': 'Feature',
#    'properties': {'name': 'Brussels'},
#    'geometry': {'type': 'Point',
#     'coordinates': (4.33137074969045, 50.83526293533032)},
#    'bbox': (4.33137074969045,
#     50.83526293533032,
#     4.33137074969045,
#     50.83526293533032)},
#   {'id': '171',
#    'type': 'Feature',
#    'properties': {'name': 'Dhaka'},
#    'geometry': {'type': 'Point',
#     'coordinates': (90.40663360810754, 23.725005570312817)},
#    'bbox': (90.40663360810754,
#     23.725005570312817,
#     90.40663360810754,
#     23.725005570312817)},
#   {'id': '172',
#    'type': 'Feature',
#    'properties': {'name': 'Luanda'},
#    'geometry': {'type': 'Point',
#     'coordinates': (13.23248118266855, -8.836340255012658)},
#    'bbox': (13.23248118266855,
#     -8.836340255012658,
#     13.23248118266855,
#     -8.836340255012658)},
#   {'id': '173',
#    'type': 'Feature',
#    'properties': {'name': 'Algiers'},
#    'geometry': {'type': 'Point',
#     'coordinates': (3.048606670909237, 36.765010656628135)},
#    'bbox': (3.048606670909237,
#     36.765010656628135,
#     3.048606670909237,
#     36.765010656628135)},
#   {'id': '174',
#    'type': 'Feature',
#    'properties': {'name': 'Rangoon'},
#    'geometry': {'type': 'Point',
# ...
#    'geometry': {'type': 'Point',
#     'coordinates': (-3.6852975446125242, 40.40197212311381)},
#    'bbox': (-3.6852975446125242,
#     40.40197212311381,
#     -3.6852975446125242,
#     40.40197212311381)},
#   {'id': '186',
#    'type': 'Feature',
#    'properties': {'name': 'Geneva'},
#    'geometry': {'type': 'Point',
#     'coordinates': (6.140028034091699, 46.21000754707626)},
#    'bbox': (6.140028034091699,
#     46.21000754707626,
#     6.140028034091699,
#     46.21000754707626)},
#   {'id': '187',
#    'type': 'Feature',
#    'properties': {'name': 'Stockholm'},
#    'geometry': {'type': 'Point',
#     'coordinates': (18.095388874180912, 59.35270581286585)},
#    'bbox': (18.095388874180912,
#     59.35270581286585,
#     18.095388874180912,
#     59.35270581286585)},
#   {'id': '188',
#    'type': 'Feature',
#    'properties': {'name': 'Bangkok'},
#    'geometry': {'type': 'Point',
#     'coordinates': (100.51469879369489, 13.751945064087977)},
#    'bbox': (100.51469879369489,
#     13.751945064087977,
#     100.51469879369489,
#     13.751945064087977)},
#   {'id': '189',
#    'type': 'Feature',
#    'properties': {'name': 'Lima'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-77.05200795343472, -12.04606681752557)},
#    'bbox': (-77.05200795343472,
#     -12.04606681752557,
#     -77.05200795343472,
#     -12.04606681752557)},
#   {'id': '190',
#    'type': 'Feature',
#    'properties': {'name': 'Dakar'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-17.47507598705056, 14.717777583623274)},
#    'bbox': (-17.47507598705056,
#     14.717777583623274,
#     -17.47507598705056,
#     14.717777583623274)},
#   {'id': '191',
#    'type': 'Feature',
#    'properties': {'name': 'Johannesburg'},
#    'geometry': {'type': 'Point',
#     'coordinates': (28.028063865019476, -26.16809888138414)},
#    'bbox': (28.028063865019476,
#     -26.16809888138414,
#     28.028063865019476,
#     -26.16809888138414)},
#   {'id': '192',
#    'type': 'Feature',
#    'properties': {'name': 'Amsterdam'},
#    'geometry': {'type': 'Point',
#     'coordinates': (4.914694317400972, 52.35191454666443)},
#    'bbox': (4.914694317400972,
#     52.35191454666443,
#     4.914694317400972,
#     52.35191454666443)},
#   {'id': '193',
#    'type': 'Feature',
#    'properties': {'name': 'Casablanca'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-7.618313291698712, 33.60192207425848)},
#    'bbox': (-7.618313291698712,
#     33.60192207425848,
#     -7.618313291698712,
#     33.60192207425848)},
#   {'id': '194',
#    'type': 'Feature',
#    'properties': {'name': 'Seoul'},
#    'geometry': {'type': 'Point',
#     'coordinates': (126.99778513820195, 37.56829495838895)},
#    'bbox': (126.99778513820195,
#     37.56829495838895,
#     126.99778513820195,
#     37.56829495838895)},
#   {'id': '195',
#    'type': 'Feature',
#    'properties': {'name': 'Manila'},
#    'geometry': {'type': 'Point',
#     'coordinates': (120.9802713035424, 14.606104813440538)},
#    'bbox': (120.9802713035424,
#     14.606104813440538,
#     120.9802713035424,
#     14.606104813440538)},
#   {'id': '196',
#    'type': 'Feature',
#    'properties': {'name': 'Monterrey'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-100.33193064232995, 25.671940995125283)},
#    'bbox': (-100.33193064232995,
#     25.671940995125283,
#     -100.33193064232995,
#     25.671940995125283)},
#   {'id': '197',
#    'type': 'Feature',
#    'properties': {'name': 'Berlin'},
#    'geometry': {'type': 'Point',
#     'coordinates': (13.399602764700546, 52.523764522251156)},
#    'bbox': (13.399602764700546,
#     52.523764522251156,
#     13.399602764700546,
#     52.523764522251156)},
#   {'id': '198',
#    'type': 'Feature',
#    'properties': {'name': 'Ürümqi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (87.57305979624726, 43.8069580850418)},
#    'bbox': (87.57305979624726,
#     43.8069580850418,
#     87.57305979624726,
#     43.8069580850418)},
#   {'id': '199',
#    'type': 'Feature',
#    'properties': {'name': 'Chengdu'},
#    'geometry': {'type': 'Point',
#     'coordinates': (104.06807363094873, 30.671945877957796)},
#    'bbox': (104.06807363094873,
#     30.671945877957796,
#     104.06807363094873,
#     30.671945877957796)},
#   {'id': '200',
#    'type': 'Feature',
#    'properties': {'name': '?saka'},
#    'geometry': {'type': 'Point',
#     'coordinates': (135.4581989565952, 34.75198107491417)},
#    'bbox': (135.4581989565952,
#     34.75198107491417,
#     135.4581989565952,
#     34.75198107491417)},
#   {'id': '201',
#    'type': 'Feature',
#    'properties': {'name': 'Kinshasa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (15.313026023171744, -4.327778243275986)},
#    'bbox': (15.313026023171744,
#     -4.327778243275986,
#     15.313026023171744,
#     -4.327778243275986)},
#   {'id': '202',
#    'type': 'Feature',
#    'properties': {'name': 'New Delhi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (77.19998002005303, 28.600023009245433)},
#    'bbox': (77.19998002005303,
#     28.600023009245433,
#     77.19998002005303,
#     28.600023009245433)},
#   {'id': '203',
#    'type': 'Feature',
#    'properties': {'name': 'Bangalore'},
#    'geometry': {'type': 'Point',
#     'coordinates': (77.55806386521755, 12.97194099507442)},
#    'bbox': (77.55806386521755,
#     12.97194099507442,
#     77.55806386521755,
#     12.97194099507442)},
#   {'id': '204',
#    'type': 'Feature',
#    'properties': {'name': 'Athens'},
#    'geometry': {'type': 'Point',
#     'coordinates': (23.731375225679358, 37.98527209055226)},
#    'bbox': (23.731375225679358,
#     37.98527209055226,
#     23.731375225679358,
#     37.98527209055226)},
#   {'id': '205',
#    'type': 'Feature',
#    'properties': {'name': 'Baghdad'},
#    'geometry': {'type': 'Point',
#     'coordinates': (44.391922914564134, 33.34059435615865)},
#    'bbox': (44.391922914564134,
#     33.34059435615865,
#     44.391922914564134,
#     33.34059435615865)},
#   {'id': '206',
#    'type': 'Feature',
#    'properties': {'name': 'Addis Ababa'},
#    'geometry': {'type': 'Point',
#     'coordinates': (38.69805857534868, 9.035256221295754)},
#    'bbox': (38.69805857534868,
#     9.035256221295754,
#     38.69805857534868,
#     9.035256221295754)},
#   {'id': '207',
#    'type': 'Feature',
#    'properties': {'name': 'Tehran'},
#    'geometry': {'type': 'Point',
#     'coordinates': (51.42239817500899, 35.673888627001304)},
#    'bbox': (51.42239817500899,
#     35.673888627001304,
#     51.42239817500899,
#     35.673888627001304)},
#   {'id': '208',
#    'type': 'Feature',
#    'properties': {'name': 'Vancouver'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-123.1235900763943, 49.27536244271175)},
#    'bbox': (-123.1235900763943,
#     49.27536244271175,
#     -123.1235900763943,
#     49.27536244271175)},
#   {'id': '209',
#    'type': 'Feature',
#    'properties': {'name': 'Toronto'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-79.42196665298843, 43.70192573640844)},
#    'bbox': (-79.42196665298843,
#     43.70192573640844,
#     -79.42196665298843,
#     43.70192573640844)},
#   {'id': '210',
#    'type': 'Feature',
#    'properties': {'name': 'Buenos Aires'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-58.399477232331435, -34.600555749907414)},
#    'bbox': (-58.399477232331435,
#     -34.600555749907414,
#     -58.399477232331435,
#     -34.600555749907414)},
#   {'id': '211',
#    'type': 'Feature',
#    'properties': {'name': 'Kabul'},
#    'geometry': {'type': 'Point',
#     'coordinates': (69.18131419070505, 34.51863614490031)},
#    'bbox': (69.18131419070505,
#     34.51863614490031,
#     69.18131419070505,
#     34.51863614490031)},
#   {'id': '212',
#    'type': 'Feature',
#    'properties': {'name': 'Vienna'},
#    'geometry': {'type': 'Point',
#     'coordinates': (16.364693096743736, 48.20196113681686)},
#    'bbox': (16.364693096743736,
#     48.20196113681686,
#     16.364693096743736,
#     48.20196113681686)},
#   {'id': '213',
#    'type': 'Feature',
#    'properties': {'name': 'Melbourne'},
#    'geometry': {'type': 'Point',
#     'coordinates': (144.97307037590406, -37.81808545369631)},
#    'bbox': (144.97307037590406,
#     -37.81808545369631,
#     144.97307037590406,
#     -37.81808545369631)},
#   {'id': '214',
#    'type': 'Feature',
#    'properties': {'name': 'Taipei'},
#    'geometry': {'type': 'Point',
#     'coordinates': (121.568333333333, 25.0358333333333)},
#    'bbox': (121.568333333333,
#     25.0358333333333,
#     121.568333333333,
#     25.0358333333333)},
#   {'id': '215',
#    'type': 'Feature',
#    'properties': {'name': 'Auckland'},
#    'geometry': {'type': 'Point',
#     'coordinates': (174.76302698707957, -36.848054894932005)},
#    'bbox': (174.76302698707957,
#     -36.848054894932005,
#     174.76302698707957,
#     -36.848054894932005)},
#   {'id': '216',
#    'type': 'Feature',
#    'properties': {'name': 'Los Angeles'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-118.18192636994041, 33.99192410876543)},
#    'bbox': (-118.18192636994041,
#     33.99192410876543,
#     -118.18192636994041,
#     33.99192410876543)},
#   {'id': '217',
#    'type': 'Feature',
#    'properties': {'name': 'Washington, D.C.'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-77.01136443943716, 38.901495235087054)},
#    'bbox': (-77.01136443943716,
#     38.901495235087054,
#     -77.01136443943716,
#     38.901495235087054)},
#   {'id': '218',
#    'type': 'Feature',
#    'properties': {'name': 'New York'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-73.98196278740681, 40.75192492259464)},
#    'bbox': (-73.98196278740681,
#     40.75192492259464,
#     -73.98196278740681,
#     40.75192492259464)},
#   {'id': '219',
#    'type': 'Feature',
#    'properties': {'name': 'London'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-0.11866770247593195, 51.5019405883275)},
#    'bbox': (-0.11866770247593195,
#     51.5019405883275,
#     -0.11866770247593195,
#     51.5019405883275)},
#   {'id': '220',
#    'type': 'Feature',
#    'properties': {'name': 'Istanbul'},
#    'geometry': {'type': 'Point',
#     'coordinates': (29.008055727002613, 41.10694201243979)},
#    'bbox': (29.008055727002613,
#     41.10694201243979,
#     29.008055727002613,
#     41.10694201243979)},
#   {'id': '221',
#    'type': 'Feature',
#    'properties': {'name': 'Riyadh'},
#    'geometry': {'type': 'Point',
#     'coordinates': (46.770795798688255, 24.642779007816443)},
#    'bbox': (46.770795798688255,
#     24.642779007816443,
#     46.770795798688255,
#     24.642779007816443)},
#   {'id': '222',
#    'type': 'Feature',
#    'properties': {'name': 'Cape Town'},
#    'geometry': {'type': 'Point',
#     'coordinates': (18.43304229922603, -33.91806510862875)},
#    'bbox': (18.43304229922603,
#     -33.91806510862875,
#     18.43304229922603,
#     -33.91806510862875)},
#   {'id': '223',
#    'type': 'Feature',
#    'properties': {'name': 'Moscow'},
#    'geometry': {'type': 'Point',
#     'coordinates': (37.6135769672714, 55.75410998124818)},
#    'bbox': (37.6135769672714,
#     55.75410998124818,
#     37.6135769672714,
#     55.75410998124818)},
#   {'id': '224',
#    'type': 'Feature',
#    'properties': {'name': 'Mexico City'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-99.1329340602939, 19.444388301415472)},
#    'bbox': (-99.1329340602939,
#     19.444388301415472,
#     -99.1329340602939,
#     19.444388301415472)},
#   {'id': '225',
#    'type': 'Feature',
#    'properties': {'name': 'Lagos'},
#    'geometry': {'type': 'Point',
#     'coordinates': (3.3895852125984334, 6.445207512093191)},
#    'bbox': (3.3895852125984334,
#     6.445207512093191,
#     3.3895852125984334,
#     6.445207512093191)},
#   {'id': '226',
#    'type': 'Feature',
#    'properties': {'name': 'Rome'},
#    'geometry': {'type': 'Point',
#     'coordinates': (12.481312562873995, 41.89790148509894)},
#    'bbox': (12.481312562873995,
#     41.89790148509894,
#     12.481312562873995,
#     41.89790148509894)},
#   {'id': '227',
#    'type': 'Feature',
#    'properties': {'name': 'Beijing'},
#    'geometry': {'type': 'Point',
#     'coordinates': (116.38633982565943, 39.93083808990906)},
#    'bbox': (116.38633982565943,
#     39.93083808990906,
#     116.38633982565943,
#     39.93083808990906)},
#   {'id': '228',
#    'type': 'Feature',
#    'properties': {'name': 'Nairobi'},
#    'geometry': {'type': 'Point',
#     'coordinates': (36.81471100047145, -1.2814008832377795)},
#    'bbox': (36.81471100047145,
#     -1.2814008832377795,
#     36.81471100047145,
#     -1.2814008832377795)},
#   {'id': '229',
#    'type': 'Feature',
#    'properties': {'name': 'Jakarta'},
#    'geometry': {'type': 'Point',
#     'coordinates': (106.82749176247012, -6.172471846798885)},
#    'bbox': (106.82749176247012,
#     -6.172471846798885,
#     106.82749176247012,
#     -6.172471846798885)},
#   {'id': '230',
#    'type': 'Feature',
#    'properties': {'name': 'Bogota'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-74.08528981377441, 4.598369421147822)},
#    'bbox': (-74.08528981377441,
#     4.598369421147822,
#     -74.08528981377441,
#     4.598369421147822)},
#   {'id': '231',
#    'type': 'Feature',
#    'properties': {'name': 'Cairo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (31.248022361126118, 30.051906205103705)},
#    'bbox': (31.248022361126118,
#     30.051906205103705,
#     31.248022361126118,
#     30.051906205103705)},
#   {'id': '232',
#    'type': 'Feature',
#    'properties': {'name': 'Shanghai'},
#    'geometry': {'type': 'Point',
#     'coordinates': (121.43455881982015, 31.218398311228327)},
#    'bbox': (121.43455881982015,
#     31.218398311228327,
#     121.43455881982015,
#     31.218398311228327)},
#   {'id': '233',
#    'type': 'Feature',
#    'properties': {'name': 'Tokyo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (139.74946157054467, 35.686962764371174)},
#    'bbox': (139.74946157054467,
#     35.686962764371174,
#     139.74946157054467,
#     35.686962764371174)},
#   {'id': '234',
#    'type': 'Feature',
#    'properties': {'name': 'Mumbai'},
#    'geometry': {'type': 'Point',
#     'coordinates': (72.85504343876647, 19.0189362343566)},
#    'bbox': (72.85504343876647,
#     19.0189362343566,
#     72.85504343876647,
#     19.0189362343566)},
#   {'id': '235',
#    'type': 'Feature',
#    'properties': {'name': 'Paris'},
#    'geometry': {'type': 'Point',
#     'coordinates': (2.33138946713035, 48.86863878981461)},
#    'bbox': (2.33138946713035,
#     48.86863878981461,
#     2.33138946713035,
#     48.86863878981461)},
#   {'id': '236',
#    'type': 'Feature',
#    'properties': {'name': 'Santiago'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-70.66898671317483, -33.448067956934096)},
#    'bbox': (-70.66898671317483,
#     -33.448067956934096,
#     -70.66898671317483,
#     -33.448067956934096)},
#   {'id': '237',
#    'type': 'Feature',
#    'properties': {'name': 'Kolkata'},
#    'geometry': {'type': 'Point',
#     'coordinates': (88.32272979950551, 22.49691515689642)},
#    'bbox': (88.32272979950551,
#     22.49691515689642,
#     88.32272979950551,
#     22.49691515689642)},
#   {'id': '238',
#    'type': 'Feature',
#    'properties': {'name': 'Rio de Janeiro'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-43.22696665284366, -22.923077315615956)},
#    'bbox': (-43.22696665284366,
#     -22.923077315615956,
#     -43.22696665284366,
#     -22.923077315615956)},
#   {'id': '239',
#    'type': 'Feature',
#    'properties': {'name': 'São Paulo'},
#    'geometry': {'type': 'Point',
#     'coordinates': (-46.62696583905523, -23.55673372837896)},
#    'bbox': (-46.62696583905523,
#     -23.55673372837896,
#     -46.62696583905523,
#     -23.55673372837896)},
#   {'id': '240',
#    'type': 'Feature',
#    'properties': {'name': 'Sydney'},
#    'geometry': {'type': 'Point',
#     'coordinates': (151.1832339501475, -33.91806510862875)},
#    'bbox': (151.1832339501475,
#     -33.91806510862875,
#     151.1832339501475,
#     -33.91806510862875)},
#   {'id': '241',
#    'type': 'Feature',
#    'properties': {'name': 'Singapore'},
#    'geometry': {'type': 'Point',
#     'coordinates': (103.85387481909902, 1.2949793251059418)},
#    'bbox': (103.85387481909902,
#     1.2949793251059418,
#     103.85387481909902,
#     1.2949793251059418)},
#   {'id': '242',
#    'type': 'Feature',
#    'properties': {'name': 'Hong Kong'},
#    'geometry': {'type': 'Point',
#     'coordinates': (114.18306345846304, 22.30692675357551)},
#    'bbox': (114.18306345846304,
#     22.30692675357551,
#     114.18306345846304,
#     22.30692675357551)}],
#  'bbox': (-175.22056447761656,
#   -41.29998785369173,
#   179.21664709402887,
#   64.15002361973922)}

# %%
m = ipyleaflet.Map(center=[48.8566, 2.3429], zoom=6)

layer = ipyleaflet.GeoJSON(data=cities.__geo_interface__)
m.add_layer(layer)
m
# Out:
# Map(center=[48.8566, 2.3429], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
m = ipyleaflet.Map(center=[48.8566, 2.3429], zoom=3)
geo_data = ipyleaflet.GeoData(
    geo_dataframe = countries,
    style={'color': 'black', 'fillColor': '#3366cc', 'opacity':0.05, 'weight':1.9, 'dashArray':'2', 'fillOpacity':0.6},
    hover_style={'fillColor': 'red' , 'fillOpacity': 0.2},
    name = 'Countries')
m.add_layer(geo_data)
m
# Out:
# Map(center=[48.8566, 2.3429], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %% [markdown]
# More: https://ipyleaflet.readthedocs.io/en/latest/api_reference/geodata.html

# %% [markdown]
# An example with folium:

# %%
import folium

# %%
m = folium.Map([48.8566, 2.3429], zoom_start=6, tiles="OpenStreetMap")
folium.GeoJson(countries).add_to(m)
folium.GeoJson(cities).add_to(m)
m

# %%
m = folium.Map([0, 0], zoom_start=1)
folium.Choropleth(geo_data=countries, data=countries, columns=['iso_a3', 'gdp_per_cap'],
             key_on='feature.properties.iso_a3', fill_color='BuGn', highlight=True).add_to(m)
m
